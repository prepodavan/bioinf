# %%
# %env TASK=ACTP_ECO27


import os
task = os.environ['TASK']
# Out:
# env: TASK=ACTP_ECO27

# %% [markdown]
# Для данного белка в юнипроте указан единственная находка в Pfam. В нем выбираем просмотр структуры (той, что в overview). В структуре меняем просмотр pdb на cdd. В структуре pfam показывает только один домен. При наведении на него видно координаты внутри белка
# | Pfam ID | Title | Название | pdb | cdd | coordinates | cdd-domain |
# |---|---|---|---|---|---|---|
# | PF00474 | Sodium:solute symporter family | Симпортер катионов натрия | 5nv9 | cd11495 | 6 - 479 | uncharacterized subgroup of the Na(+)/iodide (NIS) cotransporter subfamily; putative solute-binding domain |

# %%
from IPython import display


display.display(display.Image(filename='pf00474.logo.png'))

# %% [markdown]
# >Проанализируйте полученную диаграмму лого
#
# Некоторые позиции полностью консервативны. Например 447 и 363. Есть так же позиции, которым необходимо быть заряженными отрицательно (363 + 376), как и позиции, которым нужно быть положительными (255 + 434).
# На взгляд кажется, что вторыми по кол-ву идут полярные незаряженные, а бОльшая часть остатков неполярны

# %%
from IPython import display


display.display(display.Image(filename='B7UPN5.deeptmhmm.plot.png'))

# %% [markdown]
# График показывает позиции в белке и предсказанное положие остатков каждой позиции - в мембране, снаружи клетки, внутри клетки. Красным обозначены трансмембранные участки. Оранжевым обозначена уверенность модели в виде вероятности
# Координаты трансмембранных участков:
# |start|end|
# |-|-|
# |36|54|
# |77|93|
# |104|119|
# |153|169|
# |184|199|
# |206|223|
# |264|278|
# |298|318|
# |356|379|
# |407|423|
# |428|448|
# |463|479|
# |498|512|
#
#
# Как мне кажется по логе было довольно сложно понять, что белок яв-ся трансмембранным
